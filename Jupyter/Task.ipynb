# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B207-EB4C
#
#  Directory of C:\Users\nithishkumar.r\Libraries
#
# 15-01-2025  10:46    <DIR>          .
# 15-01-2025  10:46    <DIR>          ..
# 15-01-2025  10:14    <DIR>          .ipynb_checkpoints
# 15-01-2025  10:43             6,601 cleaned_iris.csv
# 15-01-2025  10:46            10,154 cleaned_Iris.xlsx
# 21-09-2019  17:26             5,107 Iris.csv
# 13-01-2025  14:58             3,609 Numpy.ipynb
# 13-01-2025  15:29            11,800 Pandas.ipynb
# 15-01-2025  10:46            73,457 Task.ipynb
# 04-09-2021  13:08            18,752 tips.csv
#                7 File(s)        129,480 bytes
#                3 Dir(s)  837,888,454,656 bytes free

# %%
df=pd.read_csv('Iris.csv')

# %%
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Setosa = df[df['Species'] == 'Iris-setosa']

# %%
print(Setosa)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
filter_rows = df[(df['SepalWidthCm'] > 3.5) & (df['Species'] == 'Iris-Setosa')]

# %%
print(filter_rows)
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df = df.rename(columns={'SepalWidthCm': 'Sepal_Width'})

# %%
df
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1          3.5            1.4           0.2
# 1      2            4.9          3.0            1.4           0.2
# 2      3            4.7          3.2            1.3           0.2
# 3      4            4.6          3.1            1.5           0.2
# 4      5            5.0          3.6            1.4           0.2
# ..   ...            ...          ...            ...           ...
# 145  146            6.7          3.0            5.2           2.3
# 146  147            6.3          2.5            5.0           1.9
# 147  148            6.5          3.0            5.2           2.0
# 148  149            6.2          3.4            5.4           2.3
# 149  150            5.9          3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
df['SepalArea'] = df['SepalLengthCm'] * df['Sepal_Width']

# %%
df
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1          3.5            1.4           0.2
# 1      2            4.9          3.0            1.4           0.2
# 2      3            4.7          3.2            1.3           0.2
# 3      4            4.6          3.1            1.5           0.2
# 4      5            5.0          3.6            1.4           0.2
# ..   ...            ...          ...            ...           ...
# 145  146            6.7          3.0            5.2           2.3
# 146  147            6.3          2.5            5.0           1.9
# 147  148            6.5          3.0            5.2           2.0
# 148  149            6.2          3.4            5.4           2.3
# 149  150            5.9          3.0            5.1           1.8
#
#             Species  SepalArea
# 0       Iris-setosa      17.85
# 1       Iris-setosa      14.70
# 2       Iris-setosa      15.04
# 3       Iris-setosa      14.26
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1          3.5            1.4           0.2
# 1      2            4.9          3.0            1.4           0.2
# 2      3            4.7          3.2            1.3           0.2
# 3      4            4.6          3.1            1.5           0.2
# 4      5            5.0          3.6            1.4           0.2
# ..   ...            ...          ...            ...           ...
# 145  146            6.7          3.0            5.2           2.3
# 146  147            6.3          2.5            5.0           1.9
# 147  148            6.5          3.0            5.2           2.0
# 148  149            6.2          3.4            5.4           2.3
# 149  150            5.9          3.0            5.1           1.8
#
#             Species  SepalArea
# 0       Iris-setosa      17.85
# 1       Iris-setosa      14.70
# 2       Iris-setosa      15.04
# 3       Iris-setosa      14.26
# ...

# %%
df['Species'] = df['Species'].replace('Iris-setosa', 'Setosa')

# %%
df
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1          3.5            1.4           0.2
# 1      2            4.9          3.0            1.4           0.2
# 2      3            4.7          3.2            1.3           0.2
# 3      4            4.6          3.1            1.5           0.2
# 4      5            5.0          3.6            1.4           0.2
# ..   ...            ...          ...            ...           ...
# 145  146            6.7          3.0            5.2           2.3
# 146  147            6.3          2.5            5.0           1.9
# 147  148            6.5          3.0            5.2           2.0
# 148  149            6.2          3.4            5.4           2.3
# 149  150            5.9          3.0            5.1           1.8
#
#             Species  SepalArea
# 0            Setosa      17.85
# 1            Setosa      14.70
# 2            Setosa      15.04
# 3            Setosa      14.26
# ...

# %%
df['Species'] = df['Species'].replace('Setosa', 'Iris-setosa')

# %%
df['Species'] = df['Species'].replace('Iris-setosa', 'Setosa')

# %%
df.to_csv('cleaned_iris.csv', index=False)

# %%
df
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1          3.5            1.4           0.2
# 1      2            4.9          3.0            1.4           0.2
# 2      3            4.7          3.2            1.3           0.2
# 3      4            4.6          3.1            1.5           0.2
# 4      5            5.0          3.6            1.4           0.2
# ..   ...            ...          ...            ...           ...
# 145  146            6.7          3.0            5.2           2.3
# 146  147            6.3          2.5            5.0           1.9
# 147  148            6.5          3.0            5.2           2.0
# 148  149            6.2          3.4            5.4           2.3
# 149  150            5.9          3.0            5.1           1.8
#
#             Species  SepalArea
# 0            Setosa      17.85
# 1            Setosa      14.70
# 2            Setosa      15.04
# 3            Setosa      14.26
# ...

# %%
asscending= df.sort_values(by='Sepal_Width', ascending=True)

# %%
asscending
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 60    61            5.0          2.0            3.5           1.0
# 62    63            6.0          2.2            4.0           1.0
# 119  120            6.0          2.2            5.0           1.5
# 68    69            6.2          2.2            4.5           1.5
# 41    42            4.5          2.3            1.3           0.3
# ..   ...            ...          ...            ...           ...
# 16    17            5.4          3.9            1.3           0.4
# 14    15            5.8          4.0            1.2           0.2
# 32    33            5.2          4.1            1.5           0.1
# 33    34            5.5          4.2            1.4           0.2
# 15    16            5.7          4.4            1.5           0.4
#
#              Species  SepalArea
# 60   Iris-versicolor      10.00
# 62   Iris-versicolor      13.20
# 119   Iris-virginica      13.20
# 68   Iris-versicolor      13.64
# ...

# %%
df['Species'] = df['Species'].replace('iris-Setosa', 'Setosa')

# %%
df['Species'] = df['Species'].replace('Iris-Setosa', 'Setosa')

# %%
df['Species'] = df['Species'].replace('Iris-Setosa', 'Setosa')

# %%
descending= df.sort_values(by='Sepal_Width', ascending=False)

# %%
descending
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 15    16            5.7          4.4            1.5           0.4
# 33    34            5.5          4.2            1.4           0.2
# 32    33            5.2          4.1            1.5           0.1
# 14    15            5.8          4.0            1.2           0.2
# 16    17            5.4          3.9            1.3           0.4
# ..   ...            ...          ...            ...           ...
# 87    88            6.3          2.3            4.4           1.3
# 62    63            6.0          2.2            4.0           1.0
# 68    69            6.2          2.2            4.5           1.5
# 119  120            6.0          2.2            5.0           1.5
# 60    61            5.0          2.0            3.5           1.0
#
#              Species  SepalArea
# 15            Setosa      25.08
# 33            Setosa      23.10
# 32            Setosa      21.32
# 14            Setosa      23.20
# ...

# %%
duplicates= df.duplicated()

# %%
duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
remove_duplictes = df.drop_duplicates()

# %%
remove_duplictes
# Out:
#       Id  SepalLengthCm  Sepal_Width  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1          3.5            1.4           0.2
# 1      2            4.9          3.0            1.4           0.2
# 2      3            4.7          3.2            1.3           0.2
# 3      4            4.6          3.1            1.5           0.2
# 4      5            5.0          3.6            1.4           0.2
# ..   ...            ...          ...            ...           ...
# 145  146            6.7          3.0            5.2           2.3
# 146  147            6.3          2.5            5.0           1.9
# 147  148            6.5          3.0            5.2           2.0
# 148  149            6.2          3.4            5.4           2.3
# 149  150            5.9          3.0            5.1           1.8
#
#             Species  SepalArea
# 0            Setosa      17.85
# 1            Setosa      14.70
# 2            Setosa      15.04
# 3            Setosa      14.26
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = df.to_excel('cleaned_iris.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df=df.to_excel('cleaned_iris.xlsx', index=False)
#
# AttributeError: 'NoneType' object has no attribute 'to_excel'

# %%
df_cleaned = df.dropna()

# %%
import numpy as np

# %%
df_cleaned = df.dropna()

# %%
df = None

# %%
df_cleaned = df.dropna()
